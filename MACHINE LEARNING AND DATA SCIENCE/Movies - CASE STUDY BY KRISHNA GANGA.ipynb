# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Movie+Assignment+Data.csv')

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %% [markdown]
# # ANALYSING THE DATA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
# ...

# %%
df.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %%
df.shape
# Out:
# (5043, 28)

# %%
round(100*(df.isnull().sum()/len(df.index)),2)
# Out:
# color                         0.38
# director_name                 2.06
# num_critic_for_reviews        0.99
# duration                      0.30
# director_facebook_likes       2.06
# actor_3_facebook_likes        0.46
# actor_2_name                  0.26
# actor_1_facebook_likes        0.14
# gross                        17.53
# genres                        0.00
# actor_1_name                  0.14
# movie_title                   0.00
# num_voted_users               0.00
# cast_total_facebook_likes     0.00
# actor_3_name                  0.46
# facenumber_in_poster          0.26
# plot_keywords                 3.03
# movie_imdb_link               0.00
# num_user_for_reviews          0.42
# language                      0.24
# country                       0.10
# content_rating                6.01
# budget                        9.76
# title_year                    2.14
# actor_2_facebook_likes        0.26
# imdb_score                    0.00
# aspect_ratio                  6.52
# ...

# %%
df = df[~df.gross.isnull()]
df = df[~df.aspect_ratio.isnull()]
df = df[~df.plot_keywords.isnull()]

# %%
df.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4031.000000  4030.000000              4028.000000
# mean               163.340858   109.857072               769.637041
# std                122.186137    22.741240              2990.038452
# min                  1.000000    37.000000                 0.000000
# 25%                 75.000000    95.000000                10.000000
# 50%                134.000000   106.000000                60.000000
# 75%                220.000000   120.000000               230.000000
# max                813.000000   334.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             4022.000000             4029.000000  4.031000e+03
# mean               739.084038             7488.253165  4.992915e+07
# std               1835.862627            15176.158266  6.901740e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %% [markdown]
# Now before we start cleaning the dataset further , lets remove the unwanted columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4031 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      4029 non-null   object
#  1   director_name              4028 non-null   object
#  2   num_critic_for_reviews     4031 non-null   float64
#  3   duration                   4030 non-null   float64
#  4   director_facebook_likes    4028 non-null   float64
#  5   actor_3_facebook_likes     4022 non-null   float64
#  6   actor_2_name               4028 non-null   object
#  7   actor_1_facebook_likes     4029 non-null   float64
#  8   gross                      4031 non-null   float64
#  9   genres                     4031 non-null   object
#  10  actor_1_name               4029 non-null   object
#  11  movie_title                4031 non-null   object
#  12  num_voted_users            4031 non-null   int64
# ...

# %%
df.language.isnull().sum()
# Out:
# 2

# %%
df['language'].fillna('English' , inplace = True)

# %%
df.language.isnull().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (4031, 28)

# %%
df =  df.assign(GrossM = lambda x : x.gross/1000000)
df =  df.assign(BudgetM = lambda x : x.budget/1000000)

# %%
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 5     Color     Andrew Stanton                   462.0     132.0
# ...     ...                ...                     ...       ...
# 5027  Color       Jafar Panahi                    64.0      90.0
# 5029  Color   Kiyoshi Kurosawa                    78.0     111.0
# 5033  Color      Shane Carruth                   143.0      77.0
# 5035  Color   Robert Rodriguez                    56.0      81.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# ...

# %%
df['profit'] = df['gross'] - df['budget']

# %%
df['profit']
# Out:
# 0       523505847.0
# 1         9404152.0
# 2       -44925825.0
# 3       198130642.0
# 5      -190641321.0
#            ...
# 5027       663780.0
# 5029      -905404.0
# 5033       417760.0
# 5035      2033920.0
# 5042        84122.0
# Name: profit, Length: 4031, dtype: float64

# %%
df.sort_values('profit' , ascending = False)
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 0     Color     James Cameron                   723.0     178.0
# 29    Color   Colin Trevorrow                   644.0     124.0
# 26    Color     James Cameron                   315.0     194.0
# 3024  Color      George Lucas                   282.0     125.0
# 3080  Color  Steven Spielberg                   215.0     120.0
# ...     ...               ...                     ...       ...
# 4909  Color       Jay Duplass                    93.0      84.0
# 4913  Color    Marianna Palka                    38.0      86.0
# 4944  Color    Zal Batmanglij                   136.0      85.0
# 4960  Color     Peter Chelsom                    57.0     100.0
# 5001  Color   Martin Scorsese                    71.0     117.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4031 entries, 0 to 5042
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      4029 non-null   object
#  1   director_name              4028 non-null   object
#  2   num_critic_for_reviews     4031 non-null   float64
#  3   duration                   4030 non-null   float64
#  4   director_facebook_likes    4028 non-null   float64
#  5   actor_3_facebook_likes     4022 non-null   float64
#  6   actor_2_name               4028 non-null   object
#  7   actor_1_facebook_likes     4029 non-null   float64
#  8   gross                      4031 non-null   float64
#  9   genres                     4031 non-null   object
#  10  actor_1_name               4029 non-null   object
#  11  movie_title                4031 non-null   object
#  12  num_voted_users            4031 non-null   int64
# ...

# %%
movies = df.drop('content_rating' , axis=1)
movies = df.drop('movie_imdb_link' , axis=1)
movies = df.drop('aspect_ratio' , axis=1)
movies = df.drop('movie_facebook_likes' , axis=1)
movies = df.drop('cast_total_facebook_likes' , axis=1)
movies = df.drop('facenumber_in_poster' , axis=1)
movies = df.drop('title_year' , axis=1)
movies = df.drop('country' , axis=1)
movies = df.drop('plot_keywords' , axis=1)
movies = df.drop('director_facebook_likes' , axis=1)
movies = df.drop('actor_3_facebook_likes' , axis=1)
movies = df.drop('actor_1_facebook_likes' , axis=1)
movies = df.drop('actor_2_facebook_likes' , axis=1)
movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 5     Color     Andrew Stanton                   462.0     132.0
# ...     ...                ...                     ...       ...
# 5027  Color       Jafar Panahi                    64.0      90.0
# 5029  Color   Kiyoshi Kurosawa                    78.0     111.0
# 5033  Color      Shane Carruth                   143.0      77.0
# 5035  Color   Robert Rodriguez                    56.0      81.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# ...

# %%
Top_10_Movies = movies.head(10)
Top_10_Movies
# Out:
#     color      director_name  num_critic_for_reviews  duration  \
# 0   Color      James Cameron                   723.0     178.0
# 1   Color     Gore Verbinski                   302.0     169.0
# 2   Color         Sam Mendes                   602.0     148.0
# 3   Color  Christopher Nolan                   813.0     164.0
# 5   Color     Andrew Stanton                   462.0     132.0
# 6   Color          Sam Raimi                   392.0     156.0
# 7   Color       Nathan Greno                   324.0     100.0
# 8   Color        Joss Whedon                   635.0     141.0
# 9   Color        David Yates                   375.0     153.0
# 10  Color        Zack Snyder                   673.0     183.0
#
#     director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                       0.0                   855.0   Joel David Moore
# 1                     563.0                  1000.0      Orlando Bloom
# ...

# %%
display(Top_10_Movies.drop_duplicates())
# Out:
#     color      director_name  num_critic_for_reviews  duration  \
# 0   Color      James Cameron                   723.0     178.0
# 1   Color     Gore Verbinski                   302.0     169.0
# 2   Color         Sam Mendes                   602.0     148.0
# 3   Color  Christopher Nolan                   813.0     164.0
# 5   Color     Andrew Stanton                   462.0     132.0
# 6   Color          Sam Raimi                   392.0     156.0
# 7   Color       Nathan Greno                   324.0     100.0
# 8   Color        Joss Whedon                   635.0     141.0
# 9   Color        David Yates                   375.0     153.0
# 10  Color        Zack Snyder                   673.0     183.0
#
#     director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                       0.0                   855.0   Joel David Moore
# 1                     563.0                  1000.0      Orlando Bloom
# ...

# %%
IMDb_Top_250 = df.sort_values('imdb_score' , ascending = False)
IMDb_Top_250 = IMDb_Top_250[IMDb_Top_250.num_voted_users > 25000]
IMDb_Top_250 = IMDb_Top_250.head(250)
IMDb_Top_250['Rank'] = range(1,251)
IMDb_Top_250
# Out:
#       color         director_name  num_critic_for_reviews  duration  \
# 1937  Color        Frank Darabont                   199.0     142.0
# 3466  Color  Francis Ford Coppola                   208.0     175.0
# 2837  Color  Francis Ford Coppola                   149.0     220.0
# 66    Color     Christopher Nolan                   645.0     152.0
# 339   Color         Peter Jackson                   328.0     192.0
# ...     ...                   ...                     ...       ...
# 4415  Color      Fabián Bielinsky                    94.0     114.0
# 0     Color         James Cameron                   723.0     178.0
# 1871  Color          Pierre Morel                   309.0      93.0
# 1993  Color       Roger Donaldson                   126.0     127.0
# 162   Color          Dean DeBlois                   292.0     102.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 1937                      0.0                   461.0    Jeffrey DeMunn
# ...

# %%
IMDb_Top_250['language']
# Out:
# 1937    English
# 3466    English
# 2837    English
# 66      English
# 339     English
#          ...
# 4415    Spanish
# 0       English
# 1871    English
# 1993    English
# 162     English
# Name: language, Length: 250, dtype: object

# %%
Top_Foreign_Lang_Film = IMDb_Top_250.loc[~(IMDb_Top_250.language == 'English')]

# %%
Top_10_Director=movies.sort_values("director_name")
Top_10_Director=Top_10_Director.groupby('director_name').imdb_score.mean()
Top_10_Director
# Out:
# director_name
# Aaron Schneider       7.100
# Aaron Seltzer         2.700
# Abel Ferrara          6.600
# Adam Brooks           7.200
# Adam Goldberg         5.400
#                       ...
# Zack Snyder           7.175
# Zak Penn              6.600
# Zal Batmanglij        6.800
# Álex de la Iglesia    6.100
# Émile Gaudreault      6.700
# Name: imdb_score, Length: 1789, dtype: float64

# %%
Top_10_Director=Top_10_Director.nlargest(10)
Top_10_Director=pd.DataFrame(Top_10_Director)
Top_10_Director
# Out:
#                    imdb_score
# director_name
# Charles Chaplin      8.600000
# Tony Kaye            8.600000
# Alfred Hitchcock     8.500000
# Damien Chazelle      8.500000
# Majid Majidi         8.500000
# Ron Fricke           8.500000
# Sergio Leone         8.433333
# Christopher Nolan    8.425000
# Asghar Farhadi       8.400000
# Catherine Owens      8.400000

# %%
df.genres.value_counts()
# Out:
# Drama                                  169
# Comedy|Drama|Romance                   162
# Comedy                                 158
# Comedy|Drama                           156
# Comedy|Romance                         135
#                                       ...
# Fantasy|Horror|Romance                   1
# Adventure|Comedy|Sci-Fi|Western          1
# Action|Biography|Drama|Thriller|War      1
# Action|Fantasy|Western                   1
# Comedy|Crime|Horror                      1
# Name: genres, Length: 777, dtype: int64

# %%
df[["genre_1","genre_2","to be dropped"]]=movies.genres.str.split('|',2,expand=True)
df[['movie_title','genres',"genre_1","genre_2","to be dropped"]]
# Out:
#                                     movie_title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 5                                  John Carter
# ...                                         ...
# 5027                                The Circle
# 5029                                  The Cure
# 5033                                    Primer
# 5035                               El Mariachi
# 5042                         My Date with Drew
#
#                                    genres      genre_1    genre_2  \
# 0         Action|Adventure|Fantasy|Sci-Fi       Action  Adventure
# 1                Action|Adventure|Fantasy       Action  Adventure
# 2               Action|Adventure|Thriller       Action  Adventure
# 3                         Action|Thriller       Action   Thriller
# ...

# %%
df.drop('to be dropped' ,axis = 1)
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 5     Color     Andrew Stanton                   462.0     132.0
# ...     ...                ...                     ...       ...
# 5027  Color       Jafar Panahi                    64.0      90.0
# 5029  Color   Kiyoshi Kurosawa                    78.0     111.0
# 5033  Color      Shane Carruth                   143.0      77.0
# 5035  Color   Robert Rodriguez                    56.0      81.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# ...

# %%
df.genre_2.fillna(df.genre_1 , inplace = True)
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 5     Color     Andrew Stanton                   462.0     132.0
# ...     ...                ...                     ...       ...
# 5027  Color       Jafar Panahi                    64.0      90.0
# 5029  Color   Kiyoshi Kurosawa                    78.0     111.0
# 5033  Color      Shane Carruth                   143.0      77.0
# 5035  Color   Robert Rodriguez                    56.0      81.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# ...

# %%
df.shape
# Out:
# (4031, 34)

# %%
PopGenre = df.sort_values(by='gross' , ascending = False)
PopGenre = df.groupby('genres').gross.mean()
PopGenre = PopGenre.nlargest(5)
PopGenre = pd.DataFrame(PopGenre)
PopGenre
# Out:
#                                                         gross
# genres
# Family|Sci-Fi                                    4.349495e+08
# Adventure|Animation|Drama|Family|Musical         4.227838e+08
# Adventure|Animation|Comedy|Drama|Family|Fantasy  3.564544e+08
# Action|Biography|Drama|History|Thriller|War      3.501236e+08
# Action|Adventure|Fantasy|Sci-Fi                  2.966848e+08

# %%
Meryl_Streep = df.loc[df.actor_1_name == 'Meryl Streep']
Leo_Caprio = df.loc[df.actor_1_name == 'Leonardo DiCaprio']
Brad_Pitt = df.loc[df.actor_1_name == 'Brad Pitt']
Combined = pd.concat([Meryl_Streep , Leo_Caprio , Brad_Pitt])
Combined = Combined.groupby(by='actor_1_name')
Combined.num_critic_for_reviews.mean()
# Out:
# actor_1_name
# Brad Pitt            245.000000
# Leonardo DiCaprio    330.190476
# Meryl Streep         181.454545
# Name: num_critic_for_reviews, dtype: float64

# %%
Combined.num_user_for_reviews.mean()
# Out:
# actor_1_name
# Brad Pitt            742.352941
# Leonardo DiCaprio    914.476190
# Meryl Streep         297.181818
# Name: num_user_for_reviews, dtype: float64

# %% [markdown]
# FROM THE ABOVE INFO WE CAN TELL THAT LEONARDO HAS THE HIGHEST OUT OF THESE ACTORS
